# %% [markdown]
# <a href="https://colab.research.google.com/github/dianabrs/ApplLLMAnacredit/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install requests

# %%
import requests
import pandas as pd

# URL del servizio JSON RESTful per Dataflow
url = "http://dataservices.imf.org/REST/SDMX_JSON.svc/Dataflow"

# Fare la richiesta GET per ottenere i dati
response = requests.get(url)

# Verifica se la richiesta è stata eseguita con successo (status code 200)
if response.status_code == 200:
    # Convertilo in formato JSON
    data1 = response.json()
    # Stampa i dati per vedere la struttura
else:
    print(f"Errore nella richiesta: {response.status_code}")
# Out:
# {'Structure': {'@xmlns:xsd': 'http://www.w3.org/2001/XMLSchema', '@xmlns:xsi': 'http://www.w3.org/2001/XMLSchema-instance', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message', '@xsi:schemaLocation': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure https://registry.sdmx.org/schemas/v2_0/SDMXStructure.xsd http://www.SDMX.org/resources/SDMXML/schemas/v2_0/message https://registry.sdmx.org/schemas/v2_0/SDMXMessage.xsd', 'Header': {'ID': '93e3eb92-beba-4e1c-b9d6-43bad163251a', 'Test': 'false', 'Prepared': '2025-02-10T14:04:27', 'Sender': {'@id': '1C0', 'Name': {'@xml:lang': 'en', '#text': 'IMF'}, 'Contact': {'URI': 'http://www.imf.org', 'Telephone': '+ 1 (202) 623-6220'}}, 'Receiver': {'@id': 'ZZZ'}}, 'Dataflows': {'Dataflow': [{'@id': 'DS-BOP_2017M06', '@version': '1.0', '@agencyID': 'IMF', '@isFinal': 'true', '@xmlns': 'http://www.SDMX.org/resources/SDMXML/schemas/v2_0/structure', 'Name': {'@xml:lang': 'en', '#text': 'Balance of Payments (BOP), 2017 M06'},
# ...

# %%
import requests
import pandas as pd

# Fai la richiesta JSON al servizio REST
url = "http://dataservices.imf.org/REST/SDMX_JSON.svc/Dataflow"
response = requests.get(url)
data = response.json()

# Estrai la parte che contiene i dati di interesse
structure = data['Structure']
dataflows = structure['Dataflows']['Dataflow']

# Crea un elenco di dizionari per le righe del DataFrame
data_list = []

for dataflow in dataflows:
    row = {
        "SOURCE": dataflow.get('@agencyID'),
        "DATABASE": dataflow.get('@id'),
        "DATABASE_ID": dataflow['KeyFamilyRef'].get('KeyFamilyID'),
        "DATABASE DESCRIPTION": dataflow['Name']['#text'],
    }
    data_list.append(row)

# Crea il DataFrame
df = pd.DataFrame(data_list)

# Aggiungi la colonna "Last Refresh Time"
df['Last Refresh Time'] = pd.to_datetime('now')

# Visualizza il DataFrame
print(df)
# Out:
#     SOURCE        DATABASE  DATABASE_ID  \
# 0      IMF  DS-BOP_2017M06  BOP_2017M06
# 1      IMF   DS-BOP_2020M3   BOP_2020M3
# 2      IMF  DS-BOP_2017M11  BOP_2017M11
# 3      IMF   DS-DOT_2020Q1   DOT_2020Q1
# 4      IMF   DS-GFSMAB2016   GFSMAB2016
# ..     ...             ...          ...
# 317    IMF       DS-GFSIBS       GFSIBS
# 318    IMF       DS-GFSMAB       GFSMAB
# 319    IMF         DS-GFSE         GFSE
# 320    IMF          DS-IFS          IFS
# 321    IMF          DS-MFS          MFS
#
#                                   DATABASE DESCRIPTION  \
# 0                  Balance of Payments (BOP), 2017 M06
# 1                  Balance of Payments (BOP), 2020 M03
# 2                  Balance of Payments (BOP), 2017 M11
# 3        Direction of Trade Statistics (DOTS), 2020 Q1
# 4    Government Finance Statistics Yearbook (GFSY 2...
# ..                                                 ...
# 317  Government Finance Statistics (GFS), Integrate...
# ...

# %%
import requests
import pandas as pd

# Fai la richiesta JSON al servizio REST
url = "http://dataservices.imf.org/REST/SDMX_JSON.svc/CompactData/IFS/M.AF+AL+IT?startPeriod=2023&endPeriod=2025"
response = requests.get(url)
data = response.json()

# Estrai la parte che contiene i dati di interesse
compact_data = data['CompactData']
data_set = compact_data['DataSet']
series = data_set['Series'][1]

 data_set
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-24-127f47e8d2ac> in <cell line: 0>()
#      16
#      17 for serie in series:
# ---> 18     for obs in serie['Column1.Obs']:
#      19         row = {
#      20             "STATO": serie.get('@REF_AREA'),
#
# KeyError: 'Column1.Obs'

# %%
data_set['Series'][2]
# Out:
# {'@FREQ': 'M',
#  '@REF_AREA': 'AL',
#  '@INDICATOR': 'FASMBLD_XDC',
#  '@UNIT_MULT': '6',
#  '@TIME_FORMAT': 'P1M',
#  'Obs': [{'@TIME_PERIOD': '2023-01', '@OBS_VALUE': '206640'},
#   {'@TIME_PERIOD': '2023-02', '@OBS_VALUE': '215980'},
#   {'@TIME_PERIOD': '2023-03', '@OBS_VALUE': '215930'},
#   {'@TIME_PERIOD': '2023-04', '@OBS_VALUE': '191230'},
#   {'@TIME_PERIOD': '2023-05', '@OBS_VALUE': '192710'},
#   {'@TIME_PERIOD': '2023-06', '@OBS_VALUE': '179910'},
#   {'@TIME_PERIOD': '2023-07', '@OBS_VALUE': '174560'},
#   {'@TIME_PERIOD': '2023-08', '@OBS_VALUE': '184810'},
#   {'@TIME_PERIOD': '2023-09', '@OBS_VALUE': '197050'},
#   {'@TIME_PERIOD': '2023-10', '@OBS_VALUE': '202810'},
#   {'@TIME_PERIOD': '2023-11', '@OBS_VALUE': '194260'},
#   {'@TIME_PERIOD': '2023-12', '@OBS_VALUE': '224110'},
#   {'@TIME_PERIOD': '2024-01', '@OBS_VALUE': '215500'},
#   {'@TIME_PERIOD': '2024-02', '@OBS_VALUE': '206230'},
#   {'@TIME_PERIOD': '2024-03', '@OBS_VALUE': '188890'},
# ...
